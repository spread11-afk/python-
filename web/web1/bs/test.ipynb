# %%
import datasource
import pandas as pd

data:list[tuple] = datasource.lastest_datetime_data()
dataFrame = pd.DataFrame(data)

'''
for items in data:
    for item in items:
        print(item)
    print("=========")
'''
dataFrame
# Out:
#                             0                    1    2             3   4   5  \
# 0      YouBike2.0_忠孝東路六段225巷口  2023-11-17 11:51:13  南港區    忠孝東路六段219號  35   0
# 1     YouBike2.0_捷運後山埤站(1號出口)  2023-11-17 11:51:13  南港區      中坡北路7號東側  53  14
# 2             YouBike2.0_合樂公園  2023-11-17 11:51:13  南港區      玉成街46號東側  15   0
# 3             YouBike2.0_合心廣場  2023-11-17 11:51:13  南港區  忠孝東路六段17號東北側  43   4
# 4             YouBike2.0_成德國中  2023-11-17 11:51:13  南港區  東新街118巷15號南側  26   0
# ...                       ...                  ...  ...           ...  ..  ..
# 1318        YouBike2.0_民福簡易綠地  2023-11-29 14:32:15  松山區    民族東路630號對側  15   4
# 1319     YouBike2.0_三民國小(撫遠街)  2023-11-29 14:32:15  松山區  撫遠街390巷27號對側  20   9
# 1320     YouBike2.0_南港公園(東新街)  2023-11-29 14:32:15  南港區  東新街170巷1號西南側  20   6
# 1321     YouBike2.0_南港公園(福德街)  2023-11-29 14:32:15  南港區     福德街383號北側  32   1
# 1322   YouBike2.0_捷運昆陽站(1號出口)  2023-11-29 14:32:15  南港區    忠孝東路六段403號  65  13
#
#        6
# 0     35
# 1     39
# ...
