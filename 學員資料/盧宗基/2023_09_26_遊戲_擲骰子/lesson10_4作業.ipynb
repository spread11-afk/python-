# %%
#  擲骰子遊戲

import random
import pyinputplus as pyip

#while True:
min = 1
max = 6
count = 0
dice1 = random.randint(min, max)
dice2 = random.randint(min, max)
dice3 = random.randint(min, max)
dice4 = random.randint(min, max)
print(dice1,dice2,dice3,dice4)
count=1
while(True): 
    if dice1!=dice2:
       if dice3==dice4:
            scores=dice3+dice4
            print(f"得得分:{scores}")

    elif dice1!=dice3:
      pass
    elif dice1!=dice4:
      pass
    else:
      answer = pyip.inputYesNo(prompt="還要繼續嗎?(y,n)",yesVal='y',noVal='n')
      if not (answer == 'y'):
          break
print("遊戲結束")
# Out:
# 5 6 6 3

# %%
#  擲骰子遊戲

import random
import pyinputplus as pyip

#while True:
min = 1
max = 6
while(True): 
  count = 0
  dice1 = random.randint(min, max)
  dice2 = random.randint(min, max)
  dice3 = random.randint(min, max)
  dice4 = random.randint(min, max)
  print(dice1,dice2,dice3,dice4)
  count=1

  if dice1==dice2==dice3==dice4:
    print(f"丟出天王:{dice1},{dice2},{dice3},{dice4}")
  elif dice1!=dice2!=dice3!=dice4:
    print(f"骰子都不同:{dice1},{dice2},{dice3},{dice4}->再擲")
    continue      
  elif dice1!=dice3:
    pass
  elif dice1!=dice4:
    pass
  else:
    answer = pyip.inputYesNo(prompt="還要繼續嗎?(y,n)",yesVal='y',noVal='n')
    if not (answer == 'y'):
        break
print("遊戲結束")
# Out:
# 6 2 3 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\User\Documents\GitHub\__11209python_school__\lesson10_4作業.ipynb 儲存格 2 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/GitHub/__11209python_school__/lesson10_4%E4%BD%9C%E6%A5%AD.ipynb#W1sZmlsZQ%3D%3D?line=13'>14</a> print(dice1,dice2,dice3,dice4)
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/GitHub/__11209python_school__/lesson10_4%E4%BD%9C%E6%A5%AD.ipynb#W1sZmlsZQ%3D%3D?line=14'>15</a> count=1
# ---> <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/GitHub/__11209python_school__/lesson10_4%E4%BD%9C%E6%A5%AD.ipynb#W1sZmlsZQ%3D%3D?line=15'>16</a> while(True):
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/GitHub/__11209python_school__/lesson10_4%E4%BD%9C%E6%A5%AD.ipynb#W1sZmlsZQ%3D%3D?line=16'>17</a>     if dice1!=dice2:
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/GitHub/__11209python_school__/lesson10_4%E4%BD%9C%E6%A5%AD.ipynb#W1sZmlsZQ%3D%3D?line=17'>18</a>        if dice3==dice4:
#
# KeyboardInterrupt:

# %%
#  擲骰子遊戲  V0.7

import random
import pyinputplus as pyip
min = 1
max = 6

while True:

  dice1 = random.randint(min, max)
  dice2 = random.randint(min, max)
  dice3 = random.randint(min, max)
  dice4 = random.randint(min, max)
  print("++++++++++++++++++++++++++++") 
  print(dice1,dice2,dice3,dice4)
  scores=0

  if dice1==dice2==dice3==dice4:
    print(f"丟出天王:{dice1},{dice2},{dice3},{dice4}")
  elif dice1!=dice2!=dice3!=dice4:
    print(f"骰子都不同:{dice1},{dice2},{dice3},{dice4}->再擲")
  elif (dice1==dice2) and (dice3==dice4):
    if dice1>dice3:
       scores=dice1+dice2
    else:
       scores=dice3+dice4

  elif (dice2==dice3) and (dice1==dice4):
    if dice1>dice2:
       scores=dice1+dice4
    else:
       scores=dice2+dice3

  elif (dice1==dice3) and (dice2==dice4):
    if dice1>dice2:
       scores=dice1+dice3
    else:
       scores=dice2+dice4
 
  elif dice1==dice2:
       scores=dice3+dice4

  elif dice1==dice3:
       scores=dice2+dice4

  elif dice1==dice4:
       scores=dice2+dice3

  elif dice2==dice3:
       scores=dice1+dice4

  elif dice2==dice4:
       scores=dice1+dice3

  elif dice3==dice4:
       scores=dice1+dice2
  
  print(f"得點:{scores}")

  answer = pyip.inputYesNo(prompt="還要繼續嗎?(y,n)",yesVal='y',noVal='n')
  if not (answer == 'y'):
        break
print("遊戲結束")
# Out:
# ++++++++++++++++++++++++++++
# 6 5 6 2
# 骰子都不同:6,5,6,2->再擲
# 得點:0
# 還要繼續嗎?(y,n)++++++++++++++++++++++++++++
# 6 1 6 4
# 骰子都不同:6,1,6,4->再擲
# 得點:0
# 還要繼續嗎?(y,n)++++++++++++++++++++++++++++
# 1 2 6 6
# 得點:3
# 還要繼續嗎?(y,n)++++++++++++++++++++++++++++
# 4 4 2 3
# 得點:5
# 還要繼續嗎?(y,n)++++++++++++++++++++++++++++
# 3 3 3 5
# 得點:8
# 還要繼續嗎?(y,n)遊戲結束

# %%
#  擲骰子遊戲  V0.75

import random
import pyinputplus as pyip
min = 1
max = 6

while True:
  dice1 = random.randint(min, max)
  dice2 = random.randint(min, max)
  dice3 = random.randint(min, max)
  dice4 = random.randint(min, max)
  print("++++++++++++++++++++++++++++") 
  print(dice1,dice2,dice3,dice4)
  
  n1=int(bool(dice1==dice2 and dice1==dice3 and dice1==dice4 and dice2==dice3 and dice2==dice4 and dice3==dice4))
  n2=int(bool(dice1 != dice2 and dice1 != dice3 and dice1!=dice4 and dice2!=dice3 and dice2!=dice4 and dice3!=dice4))

  scores=0

  if n1==1:
    print(f"丟出天王:{dice1},{dice2},{dice3},{dice4}")
  elif n2==1:
    print(f"骰子都不同:{dice1},{dice2},{dice3},{dice4}->再擲")
  elif (dice1==dice2) and (dice3==dice4):
    if dice1>dice3:
       scores=dice1+dice2
    else:
       scores=dice3+dice4
  elif (dice2==dice3) and (dice1==dice4):
    if dice1>dice2:
       scores=dice1+dice4
    else:
       scores=dice2+dice3
  elif (dice1==dice3) and (dice2==dice4):
    if dice1>dice2:
       scores=dice1+dice3
    else:
       scores=dice2+dice4
  elif dice1==dice2:
       if dice1==dice3 or dice1==dice4:
          print("骰子3顆相不同->再擲")  
       else:
          scores=dice3+dice4
  elif dice1==dice3:
       if dice1==dice2 or dice1==dice4:
          print("骰子3顆相不同->再擲")  
       else:
           scores=dice2+dice4
  elif dice1==dice4:
       if dice1==dice2 or dice1==dice3:
          print("骰子3顆相不同->再擲")  
       else:
           scores=dice2+dice3
  elif dice2==dice3:
       if dice2==dice1 or dice2==dice4:
          print("骰子3顆相不同->再擲")  
       else:
          scores=dice1+dice4
  elif dice2==dice4:
       if dice2==dice1 or dice1==dice3:
          print("骰子3顆相不同->再擲")  
       else:
          scores=dice1+dice3
  elif dice3==dice4:
       if dice3==dice1 or dice3==dice2:
          print("骰子3顆相不同->再擲")  
       else:
          scores=dice1+dice2
  
  print(f"得點:{scores}")
  answer = pyip.inputYesNo(prompt="還要繼續嗎?(y,n)",yesVal='y',noVal='n')
  print()
  if not (answer == 'y'):
        break
print("遊戲結束")
# Out:
# ++++++++++++++++++++++++++++
# 1 4 1 5
# 得點:9
# 還要繼續嗎?(y,n)
# ++++++++++++++++++++++++++++
# 6 3 6 4
# 得點:7
# 還要繼續嗎?(y,n)
# ++++++++++++++++++++++++++++
# 1 6 4 5
# 骰子都不同:1,6,4,5->再擲
# 得點:0
# 還要繼續嗎?(y,n)
# 遊戲結束
